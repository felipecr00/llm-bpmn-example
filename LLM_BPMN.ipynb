# %%
import xml.etree.ElementTree as ET
import json
import google.generativeai as genai


GEMINI_API_KEY = "Tu APi key aquí"

# Configure Gemini API
genai.configure(api_key=GEMINI_API_KEY)

def parse_bpmn_to_json(xml_file):
    """
    Converts a BPMN XML file into a simplified JSON format.
    """
    tree = ET.parse(xml_file)
    root = tree.getroot()

    ns = {'bpmn': 'http://www.omg.org/spec/BPMN/20100524/MODEL'}

    process_data = {"tasks": [], "gateways": [], "events": [], "flows": []}

    for task in root.findall(".//bpmn:task", ns):
        process_data["tasks"].append({"id": task.get("id"), "name": task.get("name")})

    for gateway in root.findall(".//bpmn:exclusiveGateway", ns):
        process_data["gateways"].append({"id": gateway.get("id"), "type": "Exclusive Gateway"})

    for event in root.findall(".//bpmn:startEvent", ns) + root.findall(".//bpmn:endEvent", ns):
        process_data["events"].append({"id": event.get("id"), "name": event.get("name")})

    for flow in root.findall(".//bpmn:sequenceFlow", ns):
        process_data["flows"].append({
            "id": flow.get("id"),
            "source": flow.get("sourceRef"),
            "target": flow.get("targetRef")
        })

    return json.dumps(process_data, indent=4)


import xml.etree.ElementTree as ET
import json

def bpmn_xml_to_json(file_path):
    namespaces = {
        'bpmn': 'http://www.omg.org/spec/BPMN/20100524/MODEL',
        'bpmndi': 'http://www.omg.org/spec/BPMN/20100524/DI'
    }

    # Parse the BPMN file
    tree = ET.parse(file_path)
    root = tree.getroot()
    elements = []
    flow_node_lanes = {}

    # Process Definitions
    definitions_id = root.get('id')

    # Process Collaboration and Participants
    for collaboration in root.findall('.//bpmn:collaboration', namespaces):
        collab_id = collaboration.get('id')
        elements.append({
            "$type": "bpmn:Collaboration",
            "id": collab_id,
            "$parent": definitions_id
        })

        for participant in collaboration.findall('bpmn:participant', namespaces):
            elements.append({
                "$type": "bpmn:Participant",
                "id": participant.get('id'),
                "name": participant.get('name'),
                "processRef": participant.get('processRef'),
                "$parent": collab_id
            })

        # Process Message Flows
        for message_flow in collaboration.findall('bpmn:messageFlow', namespaces):
            elements.append({
                "$type": "bpmn:MessageFlow",
                "id": message_flow.get('id'),
                "sourceRef": message_flow.get('sourceRef'),
                "targetRef": message_flow.get('targetRef'),
                "$parent": collab_id
            })

    # Process Processes and their elements
    for process in root.findall('.//bpmn:process', namespaces):
        process_id = process.get('id')

        # Process Lanes and flow node mapping
        for lane in process.findall('.//bpmn:lane', namespaces):
            lane_id = lane.get('id')
            flow_node_refs = [ref.text for ref in lane.findall('bpmn:flowNodeRef', namespaces)]

            # Record lane associations for flow nodes
            for ref in flow_node_refs:
                flow_node_lanes.setdefault(ref, []).append(lane_id)

            # Create lane element
            elements.append({
                "$type": "bpmn:Lane",
                "id": lane_id,
                "name": lane.get('name'),
                "flowNodeRef": flow_node_refs
            })

        # Process Flow Nodes (Tasks, Events, Gateways, etc.)
        for node in process.findall('*', namespaces):
            node_type = node.tag.split('}')[-1]  # Extract the type from the tag
            node_id = node.get('id')
            node_name = node.get('name')

            # Common properties for all flow nodes
            node_data = {
                "$type": f"bpmn:{node_type}",
                "id": node_id,
                "name": node_name,
                "lanes": flow_node_lanes.get(node_id, []),
                "$parent": process_id
            }

            # Handle specific properties for different node types
            if node_type == "task":
                node_data["incoming"] = [flow.text for flow in node.findall('bpmn:incoming', namespaces)]
                node_data["outgoing"] = [flow.text for flow in node.findall('bpmn:outgoing', namespaces)]
            elif node_type == "startEvent":
                node_data["outgoing"] = [flow.text for flow in node.findall('bpmn:outgoing', namespaces)]
            elif node_type == "intermediateCatchEvent":
                node_data["incoming"] = [flow.text for flow in node.findall('bpmn:incoming', namespaces)]
                node_data["outgoing"] = [flow.text for flow in node.findall('bpmn:outgoing', namespaces)]
            elif node_type in ["exclusiveGateway", "parallelGateway", "eventBasedGateway"]:
                node_data["incoming"] = [flow.text for flow in node.findall('bpmn:incoming', namespaces)]
                node_data["outgoing"] = [flow.text for flow in node.findall('bpmn:outgoing', namespaces)]

            elements.append(node_data)

        # Process Sequence Flows
        for flow in process.findall('bpmn:sequenceFlow', namespaces):
            elements.append({
                "$type": "bpmn:SequenceFlow",
                "id": flow.get('id'),
                "sourceRef": flow.get('sourceRef'),
                "targetRef": flow.get('targetRef'),
                "$parent": process_id
            })

    return json.dumps(elements, indent=2)

# %%
def ask_gemini_about_bpmn(json_model, question):

    prompt = f"""
    You are an expert in business process modeling and the BPMN 2.0 standard. I will give
    you a textual representation of a full BPMN model or only selected elements of a BPMN (e.g., a set of
    tasks and flows) and ask you questions about the process. You are supposed to answer the questions
    based on your understanding of the provided model.
    - Please take the role of a process expert who is familiar with the domain of the provided process,
    and use your domain knowledge to better understand and analyze the process, filling in any missing gaps.


    Here is a BPMN model in JSON format:

    {json_model}

    Please answer in natural language, so that any user not familiar with the BPMN standard can
    understand your answer without any technical knowledge; i.e., avoid technical terms like Task, Gate,
    flow, lane, etc.; rather use natural language to describe the behavior of the underlying process.
    {question}
    """

    model = genai.GenerativeModel("gemini-pro")  # Using Gemini Pro model
    response = model.generate_content(prompt)

    return response.text

# %%
# Example usage
bpmn_file = "caso_convalidar.bpmn"  # Replace with your BPMN file
json_model = bpmn_xml_to_json(bpmn_file)

print("BPMN Model converted to JSON:")
print(json_model)

# Ask a question about the BPMN model
question = "List all the activities of this process following the order of excecution"
response = ask_gemini_about_bpmn(json_model, question)

print("\nResponse from LLM:")
print(response)
# Out:
# BPMN Model converted to JSON:
# [
#   {
#     "$type": "bpmn:Collaboration",
#     "id": "Collaboration_0w0xj4s",
#     "$parent": "Definitions_1npih32"
#   },
#   {
#     "$type": "bpmn:Participant",
#     "id": "Participant_0rsvuff",
#     "name": "Direcci\u00f3n de docencia",
#     "processRef": "Process_0f7244c",
#     "$parent": "Collaboration_0w0xj4s"
#   },
#   {
#     "$type": "bpmn:Participant",
#     "id": "Participant_09i38fr",
#     "name": "Coordinador docente unidad acad\u00e9mica",
#     "processRef": null,
#     "$parent": "Collaboration_0w0xj4s"
#   },
#   {
#     "$type": "bpmn:Participant",
#     "id": "Participant_04pbhjg",
#     "name": "Direcci\u00f3n registro acad\u00e9mico",
#     "processRef": null,
#     "$parent": "Collaboration_0w0xj4s"
#   },
#   {
#     "$type": "bpmn:Participant",
#     "id": "Participant_05oof4y",
#     "name": "Alumno",
#     "processRef": null,
#     "$parent": "Collaboration_0w0xj4s"
#   },
#   {
#     "$type": "bpmn:MessageFlow",
#     "id": "Flow_13iltzw",
#     "sourceRef": "Participant_05oof4y",
#     "targetRef": "StartEvent_0jujsky",
#     "$parent": "Collaboration_0w0xj4s"
#   },
#   {
#     "$type": "bpmn:MessageFlow",
#     "id": "Flow_1pg1q4g",
#     "sourceRef": "Activity_0q3sdp1",
#     "targetRef": "Participant_09i38fr",
#     "$parent": "Collaboration_0w0xj4s"
#   },
#   {
#     "$type": "bpmn:MessageFlow",
#     "id": "Flow_0d4ttgb",
#     "sourceRef": "Participant_09i38fr",
#     "targetRef": "Event_04oh3lp",
#     "$parent": "Collaboration_0w0xj4s"
#   },
#   {
#     "$type": "bpmn:MessageFlow",
#     "id": "Flow_1ey7r5n",
#     "sourceRef": "Activity_1fm35ap",
#     "targetRef": "Participant_05oof4y",
#     "$parent": "Collaboration_0w0xj4s"
#   },
#   {
#     "$type": "bpmn:MessageFlow",
#     "id": "Flow_1g4rrgu",
#     "sourceRef": "Participant_05oof4y",
#     "targetRef": "Event_0x86o3o",
#     "$parent": "Collaboration_0w0xj4s"
#   },
#   {
#     "$type": "bpmn:MessageFlow",
#     "id": "Flow_1rt63o0",
#     "sourceRef": "Activity_1pumhic",
#     "targetRef": "Participant_04pbhjg",
#     "$parent": "Collaboration_0w0xj4s"
#   },
#   {
#     "$type": "bpmn:MessageFlow",
#     "id": "Flow_1hvo34b",
#     "sourceRef": "Activity_05ommtv",
#     "targetRef": "Participant_05oof4y",
#     "$parent": "Collaboration_0w0xj4s"
#   },
#   {
#     "$type": "bpmn:Lane",
#     "id": "Lane_0i716uj",
#     "name": "Asistente",
#     "flowNodeRef": [
#       "Gateway_00pzxd6",
#       "Activity_0w1qn10",
#       "Activity_0q3sdp1",
#       "StartEvent_0jujsky",
#       "Event_04oh3lp",
#       "Gateway_0n2nly8",
#       "Gateway_1pdwwv7",
#       "Activity_0o67329",
#       "Activity_0dbxil5",
#       "Gateway_1yuphy3",
#       "Gateway_0l2utu1",
#       "Gateway_0nzq55p",
#       "Activity_1pumhic",
#       "Activity_0ro45zf"
#     ]
#   },
#   {
#     "$type": "bpmn:Lane",
#     "id": "Lane_0u8n25k",
#     "name": "Subdirector",
#     "flowNodeRef": [
#       "Activity_1cecu12",
#       "Gateway_1yc8n1x",
#       "Event_0x86o3o",
#       "Activity_13nrdt8",
#       "Gateway_036crql",
#       "Gateway_05wbk3m",
#       "Activity_0kopr7q"
#     ]
#   },
#   {
#     "$type": "bpmn:Lane",
#     "id": "Lane_0afspmd",
#     "name": "Coordinador alumnos",
#     "flowNodeRef": [
#       "Activity_1fm35ap",
#       "Gateway_0x0h7gd",
#       "Gateway_1j18310",
#       "Event_0iu9cdi",
#       "Gateway_1hfbtw2",
#       "Gateway_1k0mtq6",
#       "Activity_05ommtv",
#       "Event_0a09ujb"
#     ]
#   },
#   {
#     "$type": "bpmn:laneSet",
#     "id": "LaneSet_0e093we",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:exclusiveGateway",
#     "id": "Gateway_00pzxd6",
#     "name": "\u00bfU.A. acept\u00f3?",
#     "lanes": [
#       "Lane_0i716uj"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_1a735tg"
#     ],
#     "outgoing": [
#       "Flow_1u7wgjt",
#       "Flow_1s16sz1"
#     ]
#   },
#   {
#     "$type": "bpmn:task",
#     "id": "Activity_0w1qn10",
#     "name": "Analizar solicitud",
#     "lanes": [
#       "Lane_0i716uj"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_0x1jp9o"
#     ],
#     "outgoing": [
#       "Flow_0ymom7a"
#     ]
#   },
#   {
#     "$type": "bpmn:task",
#     "id": "Activity_0q3sdp1",
#     "name": "Consultar unidad acad\u00e9mica",
#     "lanes": [
#       "Lane_0i716uj"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_1uc9ku6"
#     ],
#     "outgoing": [
#       "Flow_0psite4"
#     ]
#   },
#   {
#     "$type": "bpmn:startEvent",
#     "id": "StartEvent_0jujsky",
#     "name": "Solicitud convalidaci\u00f3n recibida",
#     "lanes": [
#       "Lane_0i716uj"
#     ],
#     "$parent": "Process_0f7244c",
#     "outgoing": [
#       "Flow_0x1jp9o"
#     ]
#   },
#   {
#     "$type": "bpmn:intermediateCatchEvent",
#     "id": "Event_04oh3lp",
#     "name": "Formulario recibido",
#     "lanes": [
#       "Lane_0i716uj"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_0psite4"
#     ],
#     "outgoing": [
#       "Flow_1a735tg"
#     ]
#   },
#   {
#     "$type": "bpmn:exclusiveGateway",
#     "id": "Gateway_0n2nly8",
#     "name": "\u00bfse ha convalidado antes?",
#     "lanes": [
#       "Lane_0i716uj"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_0ymom7a"
#     ],
#     "outgoing": [
#       "Flow_1uc9ku6",
#       "Flow_0zg87m8"
#     ]
#   },
#   {
#     "$type": "bpmn:task",
#     "id": "Activity_1cecu12",
#     "name": "Revisar aspectos reglamentarios",
#     "lanes": [
#       "Lane_0u8n25k"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_1u7wgjt"
#     ],
#     "outgoing": [
#       "Flow_0r2dgrq"
#     ]
#   },
#   {
#     "$type": "bpmn:exclusiveGateway",
#     "id": "Gateway_1yc8n1x",
#     "name": "\u00bfaprobada?",
#     "lanes": [
#       "Lane_0u8n25k"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_0r2dgrq"
#     ],
#     "outgoing": [
#       "Flow_0rwleba",
#       "Flow_0sl5pgq"
#     ]
#   },
#   {
#     "$type": "bpmn:task",
#     "id": "Activity_1fm35ap",
#     "name": "Notificar rechazo convalidaci\u00f3n",
#     "lanes": [
#       "Lane_0afspmd"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_0ka9936"
#     ],
#     "outgoing": [
#       "Flow_18soxhc"
#     ]
#   },
#   {
#     "$type": "bpmn:exclusiveGateway",
#     "id": "Gateway_0x0h7gd",
#     "name": null,
#     "lanes": [
#       "Lane_0afspmd"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_0rwleba",
#       "Flow_1s16sz1"
#     ],
#     "outgoing": [
#       "Flow_0ka9936"
#     ]
#   },
#   {
#     "$type": "bpmn:eventBasedGateway",
#     "id": "Gateway_1j18310",
#     "name": null,
#     "lanes": [
#       "Lane_0afspmd"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_18soxhc"
#     ],
#     "outgoing": [
#       "Flow_1akrn37",
#       "Flow_1suo74y"
#     ]
#   },
#   {
#     "$type": "bpmn:intermediateCatchEvent",
#     "id": "Event_0x86o3o",
#     "name": "apelaci\u00f3n\n\u00a0recibida",
#     "lanes": [
#       "Lane_0u8n25k"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_1akrn37"
#     ],
#     "outgoing": [
#       "Flow_1lxiwzz"
#     ]
#   },
#   {
#     "$type": "bpmn:intermediateCatchEvent",
#     "id": "Event_0iu9cdi",
#     "name": "plazo apelaci\u00f3n vencido",
#     "lanes": [
#       "Lane_0afspmd"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_1suo74y"
#     ],
#     "outgoing": [
#       "Flow_10k8kqw"
#     ]
#   },
#   {
#     "$type": "bpmn:task",
#     "id": "Activity_13nrdt8",
#     "name": "Revisar apelaci\u00f3n",
#     "lanes": [
#       "Lane_0u8n25k"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_1lxiwzz"
#     ],
#     "outgoing": [
#       "Flow_1entup1"
#     ]
#   },
#   {
#     "$type": "bpmn:exclusiveGateway",
#     "id": "Gateway_036crql",
#     "name": "\u00bfaceptada?",
#     "lanes": [
#       "Lane_0u8n25k"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_1entup1"
#     ],
#     "outgoing": [
#       "Flow_12fq19o",
#       "Flow_0ojxrj1"
#     ]
#   },
#   {
#     "$type": "bpmn:exclusiveGateway",
#     "id": "Gateway_05wbk3m",
#     "name": null,
#     "lanes": [
#       "Lane_0u8n25k"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_12fq19o",
#       "Flow_0sl5pgq",
#       "Flow_0zg87m8"
#     ],
#     "outgoing": [
#       "Flow_0eoc249"
#     ]
#   },
#   {
#     "$type": "bpmn:exclusiveGateway",
#     "id": "Gateway_1hfbtw2",
#     "name": null,
#     "lanes": [
#       "Lane_0afspmd"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_10k8kqw",
#       "Flow_0ojxrj1"
#     ],
#     "outgoing": [
#       "Flow_1llwxh3"
#     ]
#   },
#   {
#     "$type": "bpmn:exclusiveGateway",
#     "id": "Gateway_1k0mtq6",
#     "name": null,
#     "lanes": [
#       "Lane_0afspmd"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_1llwxh3",
#       "Flow_1s8imyh"
#     ],
#     "outgoing": [
#       "Flow_0kbl3aj"
#     ]
#   },
#   {
#     "$type": "bpmn:task",
#     "id": "Activity_05ommtv",
#     "name": "Notificar resoluci\u00f3n final",
#     "lanes": [
#       "Lane_0afspmd"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_0kbl3aj"
#     ],
#     "outgoing": [
#       "Flow_04x97y6"
#     ]
#   },
#   {
#     "$type": "bpmn:endEvent",
#     "id": "Event_0a09ujb",
#     "name": "Solicitud convalidaci\u00f3n procesada",
#     "lanes": [
#       "Lane_0afspmd"
#     ],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:parallelGateway",
#     "id": "Gateway_1pdwwv7",
#     "name": null,
#     "lanes": [
#       "Lane_0i716uj"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_0eoc249"
#     ],
#     "outgoing": [
#       "Flow_1izbfe5",
#       "Flow_1hra1py"
#     ]
#   },
#   {
#     "$type": "bpmn:task",
#     "id": "Activity_0o67329",
#     "name": "Completar formulario convalidaci\u00f3n",
#     "lanes": [
#       "Lane_0i716uj"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_1izbfe5"
#     ],
#     "outgoing": [
#       "Flow_0dc53d7"
#     ]
#   },
#   {
#     "$type": "bpmn:task",
#     "id": "Activity_0dbxil5",
#     "name": "Agregar curso a n\u00f3mina hist\u00f3rica",
#     "lanes": [
#       "Lane_0i716uj"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_12r59ji"
#     ],
#     "outgoing": [
#       "Flow_0kcawqs"
#     ]
#   },
#   {
#     "$type": "bpmn:task",
#     "id": "Activity_0kopr7q",
#     "name": "Firmar formulario convalidaci\u00f3n",
#     "lanes": [
#       "Lane_0u8n25k"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_0dc53d7"
#     ],
#     "outgoing": [
#       "Flow_0a0td2n"
#     ]
#   },
#   {
#     "$type": "bpmn:exclusiveGateway",
#     "id": "Gateway_1yuphy3",
#     "name": "\u00bfprimera vez?",
#     "lanes": [
#       "Lane_0i716uj"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_1hra1py"
#     ],
#     "outgoing": [
#       "Flow_12r59ji",
#       "Flow_1yvpstn"
#     ]
#   },
#   {
#     "$type": "bpmn:exclusiveGateway",
#     "id": "Gateway_0l2utu1",
#     "name": null,
#     "lanes": [
#       "Lane_0i716uj"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_0kcawqs",
#       "Flow_1yvpstn"
#     ],
#     "outgoing": [
#       "Flow_1o853g9"
#     ]
#   },
#   {
#     "$type": "bpmn:parallelGateway",
#     "id": "Gateway_0nzq55p",
#     "name": null,
#     "lanes": [
#       "Lane_0i716uj"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_0a0td2n",
#       "Flow_1o853g9"
#     ],
#     "outgoing": [
#       "Flow_1ajz6fw"
#     ]
#   },
#   {
#     "$type": "bpmn:task",
#     "id": "Activity_1pumhic",
#     "name": "Enviar formulario a registro acad\u00e9mico",
#     "lanes": [
#       "Lane_0i716uj"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_1ajz6fw"
#     ],
#     "outgoing": [
#       "Flow_06bbpv3"
#     ]
#   },
#   {
#     "$type": "bpmn:task",
#     "id": "Activity_0ro45zf",
#     "name": "Guardar copia en carpeta alumno",
#     "lanes": [
#       "Lane_0i716uj"
#     ],
#     "$parent": "Process_0f7244c",
#     "incoming": [
#       "Flow_06bbpv3"
#     ],
#     "outgoing": [
#       "Flow_1s8imyh"
#     ]
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_1a735tg",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_1u7wgjt",
#     "name": "s\u00ed",
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_0x1jp9o",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_0ymom7a",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_1uc9ku6",
#     "name": "no",
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_0psite4",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_1s16sz1",
#     "name": "no",
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_0zg87m8",
#     "name": "s\u00ed",
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_0r2dgrq",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_0rwleba",
#     "name": "no",
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_0sl5pgq",
#     "name": "s\u00ed",
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_0ka9936",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_18soxhc",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_1akrn37",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_1suo74y",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_1lxiwzz",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_10k8kqw",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_1entup1",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_12fq19o",
#     "name": "s\u00ed",
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_0ojxrj1",
#     "name": "no",
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_0eoc249",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_1llwxh3",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_1s8imyh",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_0kbl3aj",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_04x97y6",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_1izbfe5",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_1hra1py",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_0dc53d7",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_12r59ji",
#     "name": "s\u00ed",
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_0kcawqs",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_0a0td2n",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_1yvpstn",
#     "name": "no",
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_1o853g9",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_1ajz6fw",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:sequenceFlow",
#     "id": "Flow_06bbpv3",
#     "name": null,
#     "lanes": [],
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_1a735tg",
#     "sourceRef": "Event_04oh3lp",
#     "targetRef": "Gateway_00pzxd6",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_1u7wgjt",
#     "sourceRef": "Gateway_00pzxd6",
#     "targetRef": "Activity_1cecu12",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_0x1jp9o",
#     "sourceRef": "StartEvent_0jujsky",
#     "targetRef": "Activity_0w1qn10",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_0ymom7a",
#     "sourceRef": "Activity_0w1qn10",
#     "targetRef": "Gateway_0n2nly8",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_1uc9ku6",
#     "sourceRef": "Gateway_0n2nly8",
#     "targetRef": "Activity_0q3sdp1",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_0psite4",
#     "sourceRef": "Activity_0q3sdp1",
#     "targetRef": "Event_04oh3lp",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_1s16sz1",
#     "sourceRef": "Gateway_00pzxd6",
#     "targetRef": "Gateway_0x0h7gd",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_0zg87m8",
#     "sourceRef": "Gateway_0n2nly8",
#     "targetRef": "Gateway_05wbk3m",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_0r2dgrq",
#     "sourceRef": "Activity_1cecu12",
#     "targetRef": "Gateway_1yc8n1x",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_0rwleba",
#     "sourceRef": "Gateway_1yc8n1x",
#     "targetRef": "Gateway_0x0h7gd",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_0sl5pgq",
#     "sourceRef": "Gateway_1yc8n1x",
#     "targetRef": "Gateway_05wbk3m",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_0ka9936",
#     "sourceRef": "Gateway_0x0h7gd",
#     "targetRef": "Activity_1fm35ap",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_18soxhc",
#     "sourceRef": "Activity_1fm35ap",
#     "targetRef": "Gateway_1j18310",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_1akrn37",
#     "sourceRef": "Gateway_1j18310",
#     "targetRef": "Event_0x86o3o",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_1suo74y",
#     "sourceRef": "Gateway_1j18310",
#     "targetRef": "Event_0iu9cdi",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_1lxiwzz",
#     "sourceRef": "Event_0x86o3o",
#     "targetRef": "Activity_13nrdt8",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_10k8kqw",
#     "sourceRef": "Event_0iu9cdi",
#     "targetRef": "Gateway_1hfbtw2",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_1entup1",
#     "sourceRef": "Activity_13nrdt8",
#     "targetRef": "Gateway_036crql",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_12fq19o",
#     "sourceRef": "Gateway_036crql",
#     "targetRef": "Gateway_05wbk3m",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_0ojxrj1",
#     "sourceRef": "Gateway_036crql",
#     "targetRef": "Gateway_1hfbtw2",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_0eoc249",
#     "sourceRef": "Gateway_05wbk3m",
#     "targetRef": "Gateway_1pdwwv7",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_1llwxh3",
#     "sourceRef": "Gateway_1hfbtw2",
#     "targetRef": "Gateway_1k0mtq6",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_1s8imyh",
#     "sourceRef": "Activity_0ro45zf",
#     "targetRef": "Gateway_1k0mtq6",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_0kbl3aj",
#     "sourceRef": "Gateway_1k0mtq6",
#     "targetRef": "Activity_05ommtv",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_04x97y6",
#     "sourceRef": "Activity_05ommtv",
#     "targetRef": "Event_0a09ujb",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_1izbfe5",
#     "sourceRef": "Gateway_1pdwwv7",
#     "targetRef": "Activity_0o67329",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_1hra1py",
#     "sourceRef": "Gateway_1pdwwv7",
#     "targetRef": "Gateway_1yuphy3",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_0dc53d7",
#     "sourceRef": "Activity_0o67329",
#     "targetRef": "Activity_0kopr7q",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_12r59ji",
#     "sourceRef": "Gateway_1yuphy3",
#     "targetRef": "Activity_0dbxil5",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_0kcawqs",
#     "sourceRef": "Activity_0dbxil5",
#     "targetRef": "Gateway_0l2utu1",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_0a0td2n",
#     "sourceRef": "Activity_0kopr7q",
#     "targetRef": "Gateway_0nzq55p",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_1yvpstn",
#     "sourceRef": "Gateway_1yuphy3",
#     "targetRef": "Gateway_0l2utu1",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_1o853g9",
#     "sourceRef": "Gateway_0l2utu1",
#     "targetRef": "Gateway_0nzq55p",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_1ajz6fw",
#     "sourceRef": "Gateway_0nzq55p",
#     "targetRef": "Activity_1pumhic",
#     "$parent": "Process_0f7244c"
#   },
#   {
#     "$type": "bpmn:SequenceFlow",
#     "id": "Flow_06bbpv3",
#     "sourceRef": "Activity_1pumhic",
#     "targetRef": "Activity_0ro45zf",
#     "$parent": "Process_0f7244c"
#   }
# ]
#
# Response from Gemini:
# 1. The student submits a validation request.
# 2. The system checks if the student has already requested a validation previously.
# 3. If it is the first time, the request is sent to the academic unit for review.
# 4. If it is not the first time, the request is sent to the academic registration department to check if the student has already taken the course.
# 5. The academic unit checks the regulatory aspects of the request.
# 6. In case of approval, the request is sent to the vice-dean, otherwise, it is sent to the student coordinator for rejection notification.
# 7. The vice-dean checks if the request is approved.
# 8. In case of approval, the request is sent to the student coordinator for completion of the validation form.
# 9. In case of rejection, the request is sent to the student coordinator for rejection notification.
# 10. In case the student is appealing the decision, the request is sent to the academic coordinator.
# 11. The academic coordinator checks if the appeal is accepted.
# 12. In case of acceptance, the request is sent to the vice-dean for approval.
# 13. Otherwise, the request is sent to the student coordinator for final resolution notification.
# 14. The vice-dean checks if the request is approved.
# 15. In case of approval, the request is sent to the academic unit to complete the validation form and add the course to the student's academic record.
# 16. Otherwise, the request is sent to the student coordinator for final resolution notification.
# 17. The student completes the validation form and sends it to the academic registration department.
# 18. The academic registration department sends a copy of the form to the student's file.
# 19. The student coordinator sends the final resolution notification to the student.

# %%
question = "What happens if the academic unit doesn’t accept the form?"
response = ask_gemini_about_bpmn(json_model, question)
response
# Out:
# 'If the academic unit does not accept the form, the coordinator will be notified and he/she will notify the student.\nThe student will be given some time to correct the issue and appeal the decision.\nIf the appeal is not accepted, the convalidation request will be closed.'

# %%
question = "What is the suggested flow to easily complete the process?"
response = ask_gemini_about_bpmn(json_model, question)
response
# Out:
# "To easily complete the process, the suggested flow is as follows:\n1. A student submits a request for course validation with the education department.\n2. The education department analyzes the request and checks if the student has previously validated the course.\n3. If the student has not previously validated the course, the education department sends a request to the academic unit to check if the course can be validated.\n4. The academic unit checks if the course can be validated and sends the result back to the education department.\n5. The education department reviews the result and makes a decision on whether to approve or reject the request.\n6. If the request is approved, the education department notifies the student and sends the validation request to the academic registry.\n7. The academic registry adds the course to the student's academic record and notifies the student.\n8. If the request is rejected, the education department notifies the student and provides the reason for rejection."

# %%
question = "I'm new to the process and am confused about the alternatives for a rejection, is there anything to suggest to the sutdent in case of rejection?"
response = ask_gemini_about_bpmn(json_model, question)
response
# Out:
# "In case the student's equivalency request is rejected, the student will be notified of the rejection. The student has the possibility of appealing the rejection within a certain time frame. If the appeal is received within the specified time frame, it will be reviewed. If the appeal is accepted, the student's equivalency request will be re-evaluated. If the appeal is rejected or not received on time, the student will be notified of the final decision."
